# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav-kaushal/NLP/blob/main/Scrape_NFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# !pip install lxml
# !pip install selenium
# !apt-get update 
# !apt install chromium-chromedriver
# import libraries
import re
import csv
import json
import time
import requests
import pandas as pd
import numpy as np
from io import StringIO 
from time import sleep
from lxml import etree
from random import randint
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.2.6)

# %%
url_gm1 = 'https://opensea.io/assets?search[sortAscending]=false&search[sortBy]=LAST_SALE_DATE'

results1= requests.get(url_gm1)
web_content1 = BeautifulSoup(results1.content, 'lxml')
for search_content1 in web_content1.find('div',{"class":'Blockreact__Block-sc-18q9hu0-0 dFhPys'}):
  print(search_content1.text)
# Out:
# favorite_border0RaribleGreen snowLast0.02
# favorite_border1CryptoCinemaTaxi DriverPrice0.02 Last0
# favorite_border0play_arrowGiant SwanBlood Magic #82/100Last595
# favorite_border1Bored Ape Yacht Club4096Best Offer0.812 Last2.4
# favorite_border0play_arrowDOGIRA x BINGUS Charity CampaignDxB #6: AnthomniaLast0.11
# favorite_border0play_arrowDOGIRA x BINGUS Charity CampaignDxB #2: BBNOmulaLast0.11
# favorite_border0play_arrowDOGIRA x BINGUS Charity CampaignDxB #3: MoistCr1TiKaLLast0.11
# favorite_border0Arabian CamelsArabian Camel #9985Last0
# favorite_border0ZED RUNYoung WindsorBest Offer1.35 Last1.8
# favorite_border0play_arrowDOGIRA x BINGUS Charity CampaignDxB #4: Rocky KanakaLast0.11
# favorite_border0Strip Apes Strip Apes 2Last0.01
# favorite_border0Art Blocks CuratedSynapses #190Best Offer0.04 Last0.07
# favorite_border0play_arrowPepe ToysPepe Toy's S2 #4 - Pepe VitalikLast0.02
# favorite_border0play_arrowDOGIRA x BINGUS Charity CampaignDxB #5: Crispy ConcordsLast0.11
# favorite_border0SorareBenji Michel 2021-22 • Rare 9/100Last0.034
# favorite_border0SorareMurilo Cerqueira 2020-21 • Rare 41/100Last0.08
# favorite_border0Arabian CamelsArabian Camel #9105Best Offer0.01 Last0.05
# favorite_border0ChillmeleonsChillmeleon #1,584Last0.08
# favorite_border0Bored Ape Yacht Club5121Best Offer1.128 Last1.5
# favorite_border2Generotic Artxx #286Last0
# favorite_border5Neon District Season One ItemVice Squad MackPrice0.00002 Last0.00002
# favorite_border0play_arrowDOGIRA x BINGUS Charity CampaignDxB #1: Michael Rainey JrLast0.11
# favorite_border1EthlingsEthling #2879Last0.725
# favorite_border0ChillmeleonsChillmeleon #1,583Price1 Last0.08
# favorite_border5Neon District Season One ItemZeno Enforcer: RenegadePrice0.00002 Last0.00002
# favorite_border0play_arrowBored Ape Comic by NGBBored Ape Comic by NGBLast0.018
# favorite_border011  Tigers.Bengal TigerLast0.0011
# favorite_border0SorareJamshid Iskanderov 2021-22 • Rare 44/100Last0.008
# favorite_border0SorareBen Mines 2021-22 • Rare 9/100Last0.007
# favorite_border0RaribleRising of the sunLast1.97
# favorite_border0SorareBen Sweat 2021-22 • Rare 4/100Last0.006
# favorite_border0SorareLucas Alario 2020-21 • Rare 48/100Last0.068

# %% [markdown]
# ## WORKING CODE : using Selenium to scroll pages using chromium and then extract data using Beautifulsoup in a list format

# %% [markdown]
# ####References
# https://stackoverflow.com/questions/51046454/how-can-we-use-selenium-webdriver-in-colab-research-google-com
#
# https://medium.com/ymedialabs-innovation/web-scraping-using-beautiful-soup-and-selenium-for-dynamic-page-2f8ad15efe25
#
# https://selenium-python.readthedocs.io/locating-elements.html#locating-elements-by-class-name

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

baseUrl = 'https://opensea.io/rankings?sortBy=seven_day_volume' #(URL for the website)
collectible = [] # Empty list to collect the scraped text data
chrome_options = webdriver.ChromeOptions() # Use headless to run chrome in hidden mode in background
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
wd = webdriver.Chrome('chromedriver',chrome_options=chrome_options)
driver =webdriver.Chrome('chromedriver',chrome_options=chrome_options)
driver.get(baseUrl)  # defining url and then passing it to the beautifulsoup
for i in range(0,20):  # Use the range number from 1 to 15 or more to extract as many pages you want to scroll.
  driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
  time.sleep(10) #sleep_between_interactions based on the delay a page would take to load
  if i == 20:
    break
page_source = driver.page_source # defining page source of the entore scrolled page for beautifulsoup to work on

# Use Beautifulsoup to scrape the data after the scroll page loop is over 
web_content2 = BeautifulSoup(page_source, 'lxml')
for search_content2 in web_content2.find('div',{"class":'rankings--table-body'}):    # html class name to scrape the info from
    collectible.append(search_content2.text)  # Updating the empty list defined above
    #print(search_content2.text)
collectible_new = [word.replace('---', ' 0').replace('㆔','') for word in collectible]  # replacing the --- for 0 in the list as its not a value in the table and removing ㆔
print(*collectible_new, sep="\n")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: use options instead of chrome_options
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: use options instead of chrome_options
# ['Collection↓7 day volume7 day changetotal volumeavg priceownersassets', 'NEW1.Bored Ape Yacht Club 3,145.36295.10% 8,013.8 0.793,82110,000', 'NEW2.Rarible 1,201.3721.21% 86,649.37 0.00004141,365 0', 'NEW3.CryptoPunks 1,022.48-61.80% 177,184.35 14.542,3379,999', 'NEW4.ZED RUN 792.88-19.61% 9,376.25 0.576,80126,966', 'NEW5.Sorare 753.8-26.41% 44,245.65 0.1219,895286,950', 'NEW6.Meebits 569.7954.68% 19,707.35 4.794,64420,000', 'NEW7.Bonsai by ZENFT 543.47 0 538.17 0.271,9278,888', 'NEW8.The Sandbox 522.5817.07% 13,560.77 0.3810,603262,140', 'NEW9.VeeFriends 481.6679.77% 859.56 2.844,54410,255', 'NEW10.Ghxsts 314.44212.48% 578.03 0.85189548', 'NEW11.Decentraland 229.88-44.64% 94,663.7 8.284,54696,813', 'NEW12.Ethlings 186.38-16.75% 410.09 0.219047,777', 'NEW13.Arabian Camels 143.6-19.40% 357.19 0.051,80412,012', 'NEW14.F1® Delta Time 125.7437.29% 4,898.18 0.481,09131,487', 'NEW15.Cryptovoxels 125.5322.35% 15,815.15 2.081,2424,912', 'NEW16.MakersPlace 113.84-33.03% 13,332.46 0.889,98364,382', 'NEW17.Hashmasks 93.3135.91% 30,297.12 2.414,31616,383', 'NEW18.SuperRare 84.05-55.97% 37,128.66 2.214,12723,159', 'NEW19.Ember Sword Land 82.2-61.05% 293.62 0.142,10612,002', 'NEW20.VoxoDeus Minter 78.3335.00% 1,033.2 0.3211', 'NEW21.Art Blocks Curated 65.51-27.26% 10,053.34 0.943,87028,384', 'NEW22.Malachite 57.6558.18% 458.42 6.842596', 'NEW23.Chillmeleons 48.521921.48% 50.05 0.091811,999', 'NEW24.VoxoDeus 47.831017.79% 201.09 0.571,1263,186', 'NEW25.Justin Aversano - Twin Flames - Collection of 100 Twin Portraits 45.2564.77% 176.59 1.2164100', 'NEW26.1111 by